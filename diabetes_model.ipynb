# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('diabetes_preprocessed.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            4.0    110.0           66.0            0.0      0.0  31.9
# 1            1.0    109.0           60.0            8.0    182.0  25.4
# 2            2.0     84.0            0.0            0.0      0.0   0.0
# 3            5.0    117.0           92.0            0.0      0.0  34.1
# 4            0.0    119.0           64.0           18.0     92.0  34.9
# ..           ...      ...            ...            ...      ...   ...
# 531          4.0     83.0           86.0           19.0      0.0  29.3
# 532          2.0    141.0           58.0           34.0    128.0  25.4
# 533          4.0     90.0            0.0            0.0      0.0  28.0
# 534          6.0    134.0           70.0           23.0    130.0  35.4
# 535         13.0    126.0           90.0            0.0      0.0  43.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.471  29.0      0.0
# 1                       0.947  21.0      0.0
# 2                       0.304  21.0      0.0
# 3                       0.337  38.0      0.0
# 4                       0.725  23.0      0.0
# ..                        ...   ...      ...
# 531                     0.317  34.0      0.0
# 532                     0.699  24.0      0.0
# 533                     0.610  31.0      0.0
# 534                     0.542  29.0      1.0
# 535                     0.583  42.0      1.0
#
# [536 rows x 9 columns]

# %% [markdown]
# ## Scaling the variables

# %%
targets = df['Outcome']

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.columns.values
# Out:
# array(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype=object)

# %%
unscaled_inputs = df.columns[:-1]

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(df[unscaled_inputs])

# %%
scaled_df = pd.DataFrame(scaled_data, columns=unscaled_inputs)
scaled_df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0    -0.026481 -0.463686      -0.151051      -1.256405 -0.675364 -0.096596
# 1    -0.878108 -0.493330      -0.443867      -0.772138  0.760248 -0.884382
# 2    -0.594232 -1.234432      -3.372021      -1.256405 -0.675364 -3.962804
# 3     0.257395 -0.256178       1.117816      -1.256405 -0.675364  0.170039
# 4    -1.161983 -0.196890      -0.248656      -0.166805  0.050330  0.266997
#
#    DiabetesPedigreeFunction       Age
# 0                 -0.038767 -0.456320
# 1                  1.349807 -1.134788
# 2                 -0.525935 -1.134788
# 3                 -0.429668  0.306956
# 4                  0.702195 -0.965171

# %% [markdown]
# ## Splitting the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split(scaled_data,targets)
# Out:
# [array([[ 0.54127013, -0.19688965, -0.93189247, ..., -0.67834559,
#           2.43207785, -0.11708629],
#         [ 2.24452331, -0.58226244,  0.5321848 , ..., -1.1025377 ,
#          -1.01310227,  0.81580661],
#         [-1.16198304,  0.09955095,  1.99626208, ...,  4.16956421,
#          -0.48217696, -0.7107454 ],
#         ...,
#         [-0.87810751, -0.9083471 , -0.15105126, ..., -1.58732868,
#          -0.43841938, -0.79555385],
#         [-1.16198304,  0.36634749, -0.44386671, ...,  0.2306375 ,
#           0.14501501, -1.13478763],
#         [ 0.2573946 , -1.17514365, -0.0534461 , ..., -0.30263258,
#          -0.35090422, -0.88036229]]),
#  array([[-0.87810751, -0.25617778,  0.92260541, ...,  0.21851773,
#          -0.23713452,  0.47657283],
#         [-0.02648093, -0.4636862 , -0.15105126, ..., -0.09659641,
#          -0.03876682, -0.45632007],
#         [ 1.10902119,  0.75172028,  0.43457965, ...,  1.23657878,
#           0.09250592,  0.13733905],
#         ...,
#         [ 1.10902119, -0.16724559, -3.37202125, ..., -0.32687213,
#          -0.87891235,  0.30695594],
#         [ 2.52839884,  0.9592287 ,  2.19147238, ...,  1.16386014,
#          -0.66304163,  0.81580661],
#         [ 0.2573946 , -0.6119065 ,  0.1417642 , ...,  0.50939231,
#          -0.94892448, -0.54112851]]),
#  264    1.0
#  476    0.0
#  394    1.0
#  478    0.0
#  287    1.0
#        ...
#  383    1.0
#  1      0.0
#  149    0.0
#  512    1.0
#  164    0.0
#  Name: Outcome, Length: 402, dtype: float64,
#  426    1.0
#  0      0.0
#  94     1.0
#  254    1.0
#  523    1.0
#        ...
#  444    0.0
#  354    0.0
#  101    1.0
#  41     1.0
#  335    0.0
#  Name: Outcome, Length: 134, dtype: float64]

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled_data,targets,train_size=0.8,random_state=20)

# %%
x_train.shape
# Out:
# (428, 8)

# %%
y_train.shape
# Out:
# (428,)

# %%
x_test.shape
# Out:
# (108, 8)

# %%
y_test.shape
# Out:
# (108,)

# %% [markdown]
# ## Create model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression(penalty='l1',solver='saga',max_iter=1000,random_state=20)

# %%
reg.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000, penalty='l1', random_state=20, solver='saga')

# %%
reg.score(x_train,y_train)
# Out:
# 0.7523364485981309

# %%
model_outputs = reg.predict(x_train)

# %%
model_outputs.shape
# Out:
# (428,)

# %%
print (reg.score(x_test,y_test)*100,'%')
# Out:
# 75.0 %

# %% [markdown]
# ## Find intercepts and coefficients

# %%
reg.intercept_
# Out:
# array([-0.03164824])

# %%
reg.coef_
# Out:
# array([[ 0.44790029,  1.18435064, -0.16229852,  0.        , -0.19904526,
#          0.69349578,  0.43127151,  0.11613871]])

# %%
df.columns.values
# Out:
# array(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype=object)

# %%
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
       'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']

# %%
summary_table = pd.DataFrame(columns=['Feature Name'], data = columns)
summary_table['Coefficient'] = np.transpose(reg.coef_)
summary_table
# Out:
#                Feature Name  Coefficient
# 0               Pregnancies     0.447900
# 1                   Glucose     1.184351
# 2             BloodPressure    -0.162299
# 3             SkinThickness     0.000000
# 4                   Insulin    -0.199045
# 5                       BMI     0.693496
# 6  DiabetesPedigreeFunction     0.431272
# 7                       Age     0.116139

# %%
summary_table.index = summary_table.index+1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()

# %%
summary_table
# Out:
#                Feature Name  Coefficient
# 0                 Intercept    -0.031648
# 1               Pregnancies     0.447900
# 2                   Glucose     1.184351
# 3             BloodPressure    -0.162299
# 4             SkinThickness     0.000000
# 5                   Insulin    -0.199045
# 6                       BMI     0.693496
# 7  DiabetesPedigreeFunction     0.431272
# 8                       Age     0.116139

# %% [markdown]
# ## Interpret Coefficients

# %%
summary_table['Odds Ratio'] = np.exp(summary_table.Coefficient)
summary_table.sort_values(['Odds Ratio'], ascending=False)
# Out:
#                Feature Name  Coefficient  Odds Ratio
# 2                   Glucose     1.184351    3.268564
# 6                       BMI     0.693496    2.000697
# 1               Pregnancies     0.447900    1.565023
# 7  DiabetesPedigreeFunction     0.431272    1.539213
# 8                       Age     0.116139    1.123152
# 4             SkinThickness     0.000000    1.000000
# 0                 Intercept    -0.031648    0.968847
# 3             BloodPressure    -0.162299    0.850187
# 5                   Insulin    -0.199045    0.819513
